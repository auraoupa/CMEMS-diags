# %%
import sys
import glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy.ma as ma

# %matplotlib inline
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
sys.path.insert(0,'/home/albert/lib/python/AJ-spectre/')
from natl60_10_by_10_boxes import boxes
import plot_box as pb

# %%
database = '/media/extra/DATA/NATL60/NATL60-CJM165-S/box11/'
wbuoyfile = database + 'NATL60box11-CJM165_y2013m03.1m_wbuoy1-139_filt-n80-f0.0125.nc'
maskfile= 'NATL60box11-CJM165.1d_mask1-139_filt-n80-f0.0125.nc'

# %%
dep=xr.open_dataset(wbuoyfile)['deptht']

# %%
wbuoy_box11_m03=xr.open_dataset(wbuoyfile)['wbuoy']

# %%
wbuoy_box11_m03.shape
# Out:
# (1, 140, 921, 681)

# %%
dep.shape
# Out:
# (140,)

# %%
nav_lat=xr.open_dataset(wbuoyfile)['nav_lat']
nav_lon=xr.open_dataset(wbuoyfile)['nav_lon']

# %%
plt.pcolormesh(wbuoy_box11_m03[0,0,:,:])
plt.colorbar()

# %%
wbuoy_mean=np.nanmean(np.nanmean(wbuoy_box11_m03,axis=2),axis=2)
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:703: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)

# %%
wbuoy_mean.shape
# Out:
# (1, 140)

# %%
fig, axs = plt.subplots(1,1, figsize=(5, 5))
title = 'Mean March 2013 profile of wb - MLD'
plt.suptitle(title,size = 25,y=1.05)
axs.plot(np.squeeze(wbuoy_mean[0,0:139]),dep[0:139],'C0*-')
axs.grid(True)
axs.set_ylim(200,0)
axs.set_xlim(-2e-8,3e-8)
fig.tight_layout()

# %%
print np.squeeze(wbuoy_mean)
# Out:
# [ -3.29480995e-12   1.07057141e-09   2.29523378e-09   3.74962816e-09
#    5.27244737e-09   6.89573110e-09   8.62694449e-09   1.03955884e-08
#    1.22104078e-08   1.38498288e-08   1.54204098e-08   1.66835541e-08
#    1.83065616e-08   1.98220373e-08   2.12546070e-08   2.27749979e-08
#    2.39577531e-08   2.48691503e-08   2.56416079e-08   2.63034217e-08
#    2.67069939e-08   2.69513940e-08   2.61030273e-08   2.50637058e-08
#    2.42275853e-08   2.37797089e-08   2.20266934e-08   2.03772927e-08
#    1.92339478e-08   1.72695369e-08   1.50240265e-08   1.54914765e-08
#    1.45184647e-08   1.09995115e-08   1.90852378e-09  -4.77705386e-09
#   -1.13582166e-08  -2.19600214e-08  -2.92367428e-08  -2.93166238e-08
#   -2.78002084e-08  -2.70442300e-08  -2.78818497e-08  -2.58720902e-08
#   -2.52721435e-08  -2.29783872e-08  -2.07117896e-08  -1.90480147e-08
#   -1.52050124e-08  -3.19539439e-09   3.40259191e-07  -4.54131532e-09
#    2.31544064e-08   1.82656805e-07   2.08194962e-07   2.45728913e-08
#    9.43256353e-08   5.05692299e-07   8.53402128e-07   8.02234752e-07
#    1.04500214e-06   1.61199318e-06   1.56127533e-06   1.97053464e-06
#    1.74075365e-06   1.64922653e-06   1.19740992e-06   9.90044555e-07
#    1.35773041e-06   1.18283526e-06   9.95056837e-08  -1.60729101e-07
#   -3.23111692e-07  -7.78794060e-08   1.24907672e-07   6.72326905e-07
#    8.08571201e-07   7.22070240e-07   6.74579326e-07   7.10799725e-07
#    7.20102832e-07   8.06118123e-07   8.26749215e-07   8.51354173e-07
#    8.30549538e-07   7.64438880e-07   9.34906950e-07   8.29632711e-07
#    8.23358903e-07   6.22104494e-07   1.56879580e-07   1.48944594e-07
#   -1.00538074e-07  -1.58292117e-08  -3.75898594e-07   6.30896224e-08
#    5.54643293e-07  -4.52479343e-09   2.29468693e-08   8.11101852e-09
#   -2.01593693e-08   2.77262369e-09  -9.20683707e-09   3.61926311e-08
#    1.29501565e-08  -1.17345789e-09   8.61682015e-09   3.82532761e-09
#    5.57901769e-09   9.49504031e-09   7.86370169e-09   8.35895975e-09
#    9.01176733e-09   9.96227634e-09   1.08330704e-08   1.28943540e-08
#    1.33565656e-08   1.37748897e-08   1.31492515e-08   9.28036936e-09
#    9.88455806e-09   1.00938280e-08   1.14428946e-08   1.27648363e-08
#    1.46321337e-08   1.68334200e-08   1.99319654e-08   2.35090987e-08
#    2.63390962e-08   3.05755101e-08   3.30191199e-08   3.45286999e-08
#    3.65259112e-08   3.96529138e-08   4.23510151e-08   4.62794070e-08
#    5.04461930e-08   5.33574500e-08   5.56661170e-08  -2.16409221e-01]
