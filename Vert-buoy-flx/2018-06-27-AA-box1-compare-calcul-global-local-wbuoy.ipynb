# %%
import sys
import glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy.ma as ma

# %matplotlib inline
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
sys.path.insert(0,'/home/albert/lib/python/AJ-spectre/')
from natl60_10_by_10_boxes import boxes
import plot_box as pb

# %%
database = '/media/extra/DATA/NATL60/NATL60-CJM165-S/box1/'
buoyfile = database + 'NATL60box1-CJM165_y2013m03d01.1d_wbuoy_filt-n80-f0.0125.nc'
maskfile= 'NATL60box1-CJM165.1d_mask1-139_filt-n80-f0.0125.nc'

# %%
database2 = '/media/extra/DATA/NATL60/NATL60-CJM165-S/filt-3D/'
buoyfile2 = database2 + 'NATL60box1-CJM165_y2013m03d01.1d_wbuoy_filt-n80-f0.0125.nc'

# %%
dep=xr.open_dataset(buoyfile)['deptht']
dep2=xr.open_dataset(buoyfile2)['deptht']

# %%
buoy_box11=xr.open_dataset(buoyfile)['wbuoy']
buoy2_box11=xr.open_dataset(buoyfile2)['wbuoy']

# %%
buoy_box11.shape
# Out:
# (1, 300, 758, 601)

# %%
buoy2_box11.shape
# Out:
# (1, 139, 758, 601)

# %%
dep.shape
# Out:
# (300,)

# %%
dep2.shape
# Out:
# (139,)

# %%
nav_lat=xr.open_dataset(buoyfile)['nav_lat']
nav_lon=xr.open_dataset(buoyfile)['nav_lon']
nav_lat2=xr.open_dataset(buoyfile2)['nav_lat']
nav_lon2=xr.open_dataset(buoyfile2)['nav_lon']

# %%
fig=plt.figure(figsize=(20,7))
plt.subplot(121)
plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,0,:,:],cmap='seismic',vmin=-7e-9,vmax=7e-9)
plt.colorbar()
plt.subplot(122)
plt.pcolormesh(nav_lon2,nav_lat2,buoy2_box11[0,0,:,:],cmap='seismic',vmin=-7e-9,vmax=7e-9)
plt.colorbar()

# %%
for k in np.arange(10):
    fig=plt.figure(figsize=(20,7))
    plt.subplot(121)
    plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,k,:,:],cmap='seismic')
    plt.colorbar()
    plt.subplot(122)
    plt.pcolormesh(nav_lon2,nav_lat2,buoy2_box11[0,k,:,:],cmap='seismic')
    plt.colorbar()

# %%
fig=plt.figure(figsize=(20,7))
plt.subplot(121)
plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,138,:,:],cmap='seismic')
plt.colorbar()
plt.subplot(122)
plt.pcolormesh(nav_lon2,nav_lat2,buoy2_box11[0,138,:,:],cmap='seismic')
plt.colorbar()
