# %%
import sys
import glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy.ma as ma

# %matplotlib inline

# %%
sys.path.insert(0,'/home/albert/lib/python/AJ-spectre/')
from natl60_10_by_10_boxes import boxes
import plot_box as pb

# %%
database = '/media/extra/DATA/NATL60/NATL60-CJM165-S/box11/'
buoyfile = database + 'NATL60box11-CJM165_y2013m03d01.1d_buoyancy.nc'
buoyfile_filt = database + 'NATL60box11-CJM165_y2013m03d01.1d_buoyancy_filt-n80-f0.0125.nc'
maskfile= 'NATL60box11-CJM165.1d_mask1-139_filt-n80-f0.0125.nc'

# %%
dep=xr.open_dataset(buoyfile)['deptht']
depf=xr.open_dataset(buoyfile_filt)['deptht']

# %%
buoy_box11=xr.open_dataset(buoyfile)['sobuoy']
buoyf_box11=xr.open_dataset(buoyfile_filt)['sobuoy']

# %%
buoy_box11.shape
# Out:
# (1, 300, 953, 479)

# %%
buoyf_box11.shape
# Out:
# (1, 300, 953, 479)

# %%
dep.shape
# Out:
# (300,)

# %%
depf.shape
# Out:
# (300,)

# %%
nav_lat=xr.open_dataset(buoyfile)['nav_lat']
nav_lon=xr.open_dataset(buoyfile)['nav_lon']
nav_latf=xr.open_dataset(buoyfile_filt)['nav_lat']
nav_lonf=xr.open_dataset(buoyfile_filt)['nav_lon']

# %%
fig=plt.figure(figsize=(20,7))
plt.subplot(121)
plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,0,:,:])
plt.colorbar()
plt.subplot(122)
plt.pcolormesh(nav_lonf,nav_latf,buoyf_box11[0,0,:,:])
plt.colorbar()

# %%
for k in np.arange(10):
    fig=plt.figure(figsize=(20,7))
    plt.subplot(121)
    plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,k,:,:])
    plt.colorbar()
    plt.subplot(122)
    plt.pcolormesh(nav_lonf,nav_latf,buoyf_box11[0,k,:,:])
    plt.colorbar()

# %%
fig=plt.figure(figsize=(20,7))
plt.subplot(121)
plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,138,:,:])
plt.colorbar()
plt.subplot(122)
plt.pcolormesh(nav_lonf,nav_latf,buoyf_box11[0,138,:,:])
plt.colorbar()
