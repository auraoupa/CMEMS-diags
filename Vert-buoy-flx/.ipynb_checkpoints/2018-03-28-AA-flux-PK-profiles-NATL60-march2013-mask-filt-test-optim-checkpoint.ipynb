# %%
import sys
import glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy.ma as ma

# %matplotlib inline

# %%
sys.path.insert(0,'/mnt/meom/workdir/albert/lib/python/AJ-spectre/')
from natl60_10_by_10_boxes import boxes
import plot_box as pb

# %%
database = '/mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/'
march_buoyfiles = sorted(glob.glob(database + 'filt-3D/NATL60-CJM165_y2013m03d*.1d_buoyancy_filt-n80-f0.0125.nc'))
march_wfiles = sorted(glob.glob(database + 'filt-3D/NATL60-CJM165_y2013m03d*.1d_vovecrtz_filt-n80-f0.0125.nc'))
march_mldfiles = sorted(glob.glob(database + 'MXL/NATL60-CJM165_y2013m03d*.1d_somxl010.nc'))
maskfile= '/mnt/meom/workdir/albert/NATL60/NATL60-I/NATL60-CJM165.1d_mask1-139_filt-n80-f0.0125.nc'

# %%
dep=xr.open_dataset(march_buoyfiles[0])['deptht']

# %%
def get_values_in_box(box,data):
    jmin,jmax = box.jmin,box.jmax
    imin,imax = box.imin,box.imax
    values = data[:,0:139,jmin:jmax+1,imin:imax+1]
    return values

# %%
def Estimate_wb(box,buoy,w,tmask):
    buoy_box = get_values_in_box(box,buoy)
    w_box = get_values_in_box(box,w)  
    
    tmask_box = get_values_in_box(box,tmask)
    
    buoy_box_mask=ma.masked_where(tmask_box < 1, buoy_box)
    
    w_arr=w_box.values
    
    wb_box = np.squeeze(buoy_box_mask[0,:,:,:]*w_arr[0,:,:,:])
    avg_wb_box = np.nanmean(np.nanmean(wb_box,axis=2),axis=1)
    return avg_wb_box

# %%
def get_wb_in_boxes(buoyfiles,wfiles):
    global boxes
    _Ann_wb_arr = []
    for i in range(len(buoyfiles)): 
        print buoyfiles[i]
        buoy = xr.open_dataset(buoyfiles[i])['sobuoy']
        w = xr.open_dataset(wfiles[i])['vovecrtz']
        tmask = xr.open_dataset(maskfile)['tmask']
        _wb_arr=[]
        for box in boxes:
            print box.name
            wb = Estimate_wb(box,buoy,w,tmask)
            _wb_arr.append(wb)
        wb_arr = np.array(_wb_arr)
        _Ann_wb_arr.append(wb_arr)
    Ann_wb_arr = np.array(_Ann_wb_arr)
    return Ann_wb_arr

# %%
buoy = xr.open_dataset(march_buoyfiles[0])['sobuoy']
w = xr.open_dataset(march_wfiles[0])['vovecrtz']
tmask = xr.open_dataset(maskfile)['tmask']
box=boxes[0]

# %%
wb_boxes_march = get_wb_in_boxes(march_buoyfiles,march_wfiles)
# Out:
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d01.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d02.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d03.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d04.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d05.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d06.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d07.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d08.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d09.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d10.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d11.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d12.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d13.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d14.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d15.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d16.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d17.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d18.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d19.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d20.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d21.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d22.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d23.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d24.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d25.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d26.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d27.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d28.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d29.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d30.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-3D/NATL60-CJM165_y2013m03d31.1d_buoyancy_filt-n80-f0.0125.nc
# Box_14
# Box_13
# Box_12
# Box_11
# Box_10
# Box_7
# Box_6
# Box_5
# Box_4
# Box_3
# Box_2
# Box_1
# Box_9
# Box_8

# %%
def get_2Dvalues_in_box(box,data):
    jmin,jmax = box.jmin,box.jmax
    imin,imax = box.imin,box.imax
    values = data[:,jmin:jmax+1,imin:imax+1]
    return values

# %%
def Estimate_mld(box,mld):
    mld_box = get_2Dvalues_in_box(box,mld)
    avg_mld_box=np.nanmean(mld_box)
    return avg_mld_box

# %%
def get_mld_in_boxes(mldfiles):
    global boxes
    _Ann_mld_arr = []
    for i in range(len(mldfiles)): 
        print mldfiles[i]
        mld = xr.open_dataset(mldfiles[i])['somxl010']
        _mld_arr=[]
        for box in boxes:
            mldb = Estimate_mld(box,mld)
            _mld_arr.append(mldb)
        mld_arr = np.array(_mld_arr)
        _Ann_mld_arr.append(mld_arr)
    Ann_mld_arr = np.array(_Ann_mld_arr)
    return Ann_mld_arr

# %%
mld_boxes_march = get_mld_in_boxes(march_mldfiles)
# Out:
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d01.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d02.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d03.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d04.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d05.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d06.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d07.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d08.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d09.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d10.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d11.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d12.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d13.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d14.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d15.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d16.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d17.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d18.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d19.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d20.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d21.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d22.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d23.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d24.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d25.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d26.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d27.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d28.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d29.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d30.1d_somxl010.nc
# /mnt/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/MXL/NATL60-CJM165_y2013m03d31.1d_somxl010.nc

# %%
wb_boxes_march.shape
# Out:
# (31, 14, 139)

# %%
mld_boxes_march.shape
# Out:
# (31, 14)

# %%
fig, axs = plt.subplots(4,4, figsize=(18, 18))
axs = axs.ravel()
title = 'Mean March 2013 profile of wb - MLD'
plt.suptitle(title,size = 25,y=1.05)
i = 0
for k,box in enumerate(boxes):
    axs[i].plot(np.nanmean(wb_boxes_march[:,k,:],0),dep,'C0*-')
    axs[i].set_title(box.name,size=16)
    axs[i].grid(True)
    axs[i].set_ylim(1600,0)
    axs[i].axhline(y=np.nanmean(mld_boxes_march[:,k]),color='k')
    i = i + 1
    fig.tight_layout()
    
plt.savefig("NATL60_wb_profiles_march13.png")

# %%
fig, axs = plt.subplots(4,4, figsize=(18, 18))
axs = axs.ravel()
title = 'Mean March 2013 profile of wb - MLD'
plt.suptitle(title,size = 25,y=1.05)
i = 0
for k,box in enumerate(boxes):
    axs[i].plot(np.nanmean(wb_boxes_march[:,k,:],0),dep,'C0*-')
    axs[i].set_title(box.name,size=16)
    axs[i].grid(True)
    axs[i].set_ylim(400,0)
    axs[i].axhline(y=np.nanmean(mld_boxes_march[:,k]),color='k')
    i = i + 1
    fig.tight_layout()
    
plt.savefig("NATL60_wb_profiles_march13_surf.png")

# %%
fig, axs = plt.subplots(1,2, figsize=(9, 5))
axs = axs.ravel()
title = 'Mean March 2013 profile of wb - MLD'
plt.suptitle(title,size = 25,y=1.1)
i = 0
    
axs[i].plot(np.nanmean(wb_boxes_march[:,11,:],0),dep,'C0*-')
axs[i].set_title('Box 1 - Gulf Stream',size=16)
axs[i].grid(True)
axs[i].set_ylim(400,0)
axs[i].axhline(y=np.nanmean(mld_boxes_march[:,11]),color='k')
fig.tight_layout()
  
i = 1
    
axs[i].plot(np.nanmean(wb_boxes_march[:,3,:],0),dep,'C0*-')
axs[i].set_title('Box 11 - Labrador Sea',size=16)
axs[i].grid(True)
axs[i].set_ylim(400,0)
axs[i].axhline(y=np.nanmean(mld_boxes_march[:,3]),color='k')
fig.tight_layout()
 
plt.savefig("NATL60_box1-11_wb_profiles_march13_surf.png")

# %%
for k,box in enumerate(boxes):
    print k, box.name
# Out:
# 0 Box_14
# 1 Box_13
# 2 Box_12
# 3 Box_11
# 4 Box_10
# 5 Box_7
# 6 Box_6
# 7 Box_5
# 8 Box_4
# 9 Box_3
# 10 Box_2
# 11 Box_1
# 12 Box_9
# 13 Box_8
