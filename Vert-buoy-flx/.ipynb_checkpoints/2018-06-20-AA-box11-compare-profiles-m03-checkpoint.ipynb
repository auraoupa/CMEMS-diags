# %%
import sys
import glob
import numpy as np
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy.ma as ma

# %matplotlib inline

# %%
## modules version

print 'numpy : ',np.__version__
print 'xarray : ',xr.__version__
print 'matplotlib : ',matplotlib.__version__
# Out:
# numpy :  1.11.2
# xarray :  0.10.4
# matplotlib :  1.5.1

# %%
sys.path.insert(0,'/home/albert/lib/python/AJ-spectre/')
from natl60_10_by_10_boxes import boxes
import plot_box as pb

# %%
database = '/media/extra/DATA/NATL60/NATL60-CJM165-S/box11/'
wbuoyfile_filt = database + 'NATL60box11-CJM165_y2013m03d01.1d_wbuoy_filt-n80-f0.0125.nc'
mldfile = database + 'NATL60box11-CJM165_y2013m03d01.1d_somxl010.nc'

database2 = '/media/extra/DATA/NATL60/NATL60-CJM165-S/filt-3D/'
wbuoyfile2_filt = database2 + 'NATL60box11-CJM165_y2013m03d01.1d_wbuoy_filt-n80-f0.0125.nc'

maskfile= '/media/extra/DATA/NATL60/NATL60-I/NATL60box11-CJM165.1d_mask_filt-n80-f0.0125.nc'

# %%
depwb=xr.open_dataset(wbuoyfile_filt)['deptht']
depwb2=xr.open_dataset(wbuoyfile2_filt)['deptht']

# %%
wbuoy_box11=xr.open_dataset(wbuoyfile_filt)['wbuoy']
wbuoy2_box11=xr.open_dataset(wbuoyfile2_filt)['wbuoy']
mld=xr.open_dataset(mldfile)['somxl010']

# %%
mask=xr.open_dataset(maskfile)['tmask']

# %%
wbuoy_box11.shape
# Out:
# (1, 300, 953, 479)

# %%
wbuoy2_box11.shape
# Out:
# (1, 139, 953, 479)

# %%
mld.shape
# Out:
# (1, 953, 479)

# %%
mask.shape
# Out:
# (1, 300, 953, 479)

# %%
depwb.shape
# Out:
# (300,)

# %%
mean_wbuoy_box11=np.nanmean(np.nanmean(wbuoy_box11[0,:,:,:],1),1)
mean_wbuoy2_box11=np.nanmean(np.nanmean(wbuoy2_box11[0,:,:,:],1),1)
mean_mld=np.nanmean(mld[0,:,:])

# %%
mean_wbuoy_box11.shape
# Out:
# (300,)

# %%
mean_wbuoy2_box11.shape
# Out:
# (139,)

# %%
mean_mld
# Out:
# 199.52249

# %%
mean_wbuoy_box11
# Out:
# array([  2.52967027e-12,   1.04879427e-09,   2.25297248e-09,
#          3.59198782e-09,   5.10216003e-09,   6.64979627e-09,
#          8.39582626e-09,   1.01723732e-08,   1.20088011e-08,
#          1.39031986e-08,   1.57782427e-08,   1.76623072e-08,
#          1.94031529e-08,   2.11433218e-08,   2.27094521e-08,
#          2.41893066e-08,   2.55603343e-08,   2.67375260e-08,
#          2.77058820e-08,   2.84403772e-08,   2.89063689e-08,
#          2.90691613e-08,   2.90111632e-08,   2.86305291e-08,
#          2.79824182e-08,   2.71028693e-08,   2.60202047e-08,
#          2.47878020e-08,   2.34556303e-08,   2.20856631e-08,
#          2.07009165e-08,   1.93457961e-08,   1.80773814e-08,
#          1.67082828e-08,   1.57521303e-08,   1.40986502e-08,
#          1.31708520e-08,   1.15959153e-08,   1.07876934e-08,
#          9.83947235e-09,   9.29468236e-09,   8.61000604e-09,
#          8.11160827e-09,   7.73770914e-09,   7.36042249e-09,
#          7.04053793e-09,   6.74563250e-09,   6.41419051e-09,
#          7.02926606e-09,   5.83955995e-09,   5.60085267e-09,
#          5.33751932e-09,   5.03794872e-09,   4.90170171e-09,
#          4.63735317e-09,   4.42893544e-09,   4.28021973e-09,
#          4.12803214e-09,   3.91627175e-09,   3.78766263e-09,
#          3.62490460e-09,   3.41917850e-09,   3.26789107e-09,
#          3.11945625e-09,   2.95654612e-09,   2.81068191e-09,
#          2.66979461e-09,   2.52788834e-09,   2.38641418e-09,
#          2.24789587e-09,   2.14556395e-09,   2.00840278e-09,
#          1.86969618e-09,   1.79576032e-09,   1.67777858e-09,
#          1.53516111e-09,   1.46942913e-09,   1.35098788e-09,
#          1.26344146e-09,   1.13672183e-09,   1.04235376e-09,
#          9.61057345e-10,   8.78375206e-10,   7.98514421e-10,
#          7.26007254e-10,   6.66802447e-10,   6.04853501e-10,
#          5.27810184e-10,   4.69617845e-10,   4.12339052e-10,
#          3.64895891e-10,   3.13733872e-10,   2.70088840e-10,
#          2.30645378e-10,   1.87096144e-10,   1.63456193e-10,
#          1.30271793e-10,   1.02356255e-10,   7.90900193e-11,
#          6.21575083e-11,   4.81489744e-11,   4.24294801e-11,
#          3.47178258e-11,   2.64723746e-11,   1.45804480e-11,
#          1.70540752e-11,   1.45241241e-11,  -1.44737998e-11,
#          1.37092360e-11,  -5.34590341e-12,  -7.20386511e-12,
#          1.43337278e-11,  -3.43941260e-12,   1.23206141e-11,
#          1.17449305e-11,   1.79004110e-12,   5.59225322e-12,
#          7.01509640e-12,   6.00298847e-12,   1.36058257e-11,
#          1.94024449e-11,   3.05016012e-11,   3.72217673e-11,
#          4.16714267e-11,   5.48070131e-11,   6.53725615e-11,
#          7.35072628e-11,   8.91362748e-11,   9.30906949e-11,
#          1.06910834e-10,   1.16167298e-10,   1.23465738e-10,
#          1.34067216e-10,   1.42027251e-10,   1.49288026e-10,
#          1.55771021e-10,   1.60219199e-10,   1.63891650e-10,
#          1.75996051e-10,  -2.34170526e-01,  -2.33997688e-01,
#         -2.33814642e-01,  -2.33620241e-01,  -2.33436659e-01,
#         -2.33230859e-01,  -2.33028024e-01,  -2.32770517e-01,
#         -2.32497305e-01,  -2.32222840e-01,  -2.31946528e-01,
#         -2.31644243e-01,  -2.31358111e-01,  -2.31021345e-01,
#         -2.30712712e-01,  -2.30405763e-01,  -2.30100453e-01,
#         -2.29797393e-01,  -2.29498386e-01,  -2.29178697e-01,
#         -2.28861183e-01,  -2.28493601e-01,  -2.28149310e-01,
#         -2.27821082e-01,  -2.27505296e-01,  -2.27176130e-01,
#         -2.26865470e-01,  -2.26511911e-01,  -2.26150289e-01,
#         -2.25758553e-01,  -2.25373149e-01,  -2.24979848e-01,
#         -2.24565834e-01,  -2.24139065e-01,  -2.23701909e-01,
#         -2.23250121e-01,  -2.22782522e-01,  -2.22280532e-01,
#         -2.21773654e-01,  -2.21231163e-01,  -2.20650151e-01,
#         -2.20042676e-01,  -2.19424382e-01,  -2.18771309e-01,
#         -2.18034610e-01,  -2.17200547e-01,  -2.16356978e-01,
#         -2.15475634e-01,  -2.14633062e-01,  -2.13782817e-01,
#         -2.12954566e-01,  -2.12006062e-01,  -2.10973382e-01,
#         -2.09869251e-01,  -2.08687663e-01,  -2.07321987e-01,
#         -2.05946296e-01,  -2.04492554e-01,  -2.03094482e-01,
#         -2.01777861e-01,  -2.00449392e-01,  -1.98950619e-01,
#         -1.97353140e-01,  -1.95651531e-01,  -1.93951726e-01,
#         -1.92130804e-01,  -1.90297112e-01,  -1.88463256e-01,
#         -1.86620802e-01,  -1.84546232e-01,  -1.82288244e-01,
#         -1.79758281e-01,  -1.76996097e-01,  -1.73780486e-01,
#         -1.70040339e-01,  -1.65363386e-01,  -1.59605443e-01,
#         -1.53824106e-01,  -1.46307990e-01,  -1.37483075e-01,
#         -1.28064245e-01,  -1.18985534e-01,  -1.08929515e-01,
#         -9.87257361e-02,  -8.71972814e-02,  -7.78858215e-02,
#         -6.92233518e-02,  -5.98557927e-02,  -5.32486066e-02,
#         -4.79210876e-02,  -4.29086201e-02,  -3.86841893e-02,
#         -3.49224694e-02,  -3.13046835e-02,  -2.77964864e-02,
#         -2.49197874e-02,  -2.22275145e-02,  -1.95328221e-02,
#         -1.73431113e-02,  -1.54360114e-02,  -1.36041101e-02,
#         -1.17390500e-02,  -9.21775959e-03,  -7.27676135e-03,
#         -5.37132472e-03,  -3.45023698e-03,  -1.55503594e-03,
#         -2.03993535e-04,   7.28844840e-04,   1.12778333e-03,
#          1.37546344e-03,   1.50080933e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03,
#          1.54419907e-03,   1.54419907e-03,   1.54419907e-03], dtype=float32)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


fig, axs = plt.subplots(1,2, figsize=(10, 5))
axs = axs.ravel()
title = 'Mean March 2013 profile of wb - MLD'
plt.suptitle(title,size = 25,y=1.05)

axs[0].plot(mean_wbuoy_box11,depwb,'.-',color=colors[0])
axs[0].grid(True)
axs[0].set_ylim(1600,0)
axs[0].set_xlim(-0.5e-8,3e-8)
axs[0].axhline(y=mean_mld,color='k')
fig.tight_layout()

axs[1].plot(mean_wbuoy2_box11,depwb2,'b.-')
axs[1].grid(True)
axs[1].set_ylim(1600,0)
axs[1].set_xlim(-4e-8,3e-8)
axs[1].axhline(y=mean_mld,color='k')
fig.tight_layout()

# %%
fig=plt.figure(figsize=(20,15))
plt.subplot(221)
plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,1,:,:]*w_box11[0,1,:,:]*mask[0,1,:,:],vmin=-1e-8,vmax=3e-8)
plt.colorbar()
plt.subplot(222)
plt.pcolormesh(nav_lonwb,nav_latwb,wbuoy_box11[0,1,:,:],vmin=-1e-8,vmax=3e-8)
plt.colorbar()
plt.subplot(224)
plt.pcolormesh(nav_lonm,nav_latm,mask[0,1,:,:])
plt.colorbar()
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/matplotlib/colors.py:581: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)

# %%
fig=plt.figure(figsize=(20,15))
plt.subplot(221)
plt.pcolormesh(nav_lon,nav_lat,buoy_box11[0,1,:,:]*w_box11[0,1,:,:]*mask[0,1,:,:],vmin=-1e-8,vmax=3e-8)
plt.colorbar()
plt.subplot(222)
plt.pcolormesh(nav_lonwb,nav_latwb,wbuoy2_box11[0,0,:,:],vmin=-1e-8,vmax=3e-8)
plt.colorbar()
plt.subplot(224)
plt.pcolormesh(nav_lonm,nav_latm,mask[0,1,:,:],vmin=0,vmax=2)
plt.colorbar()
