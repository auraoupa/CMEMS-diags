# %% [markdown]
# # Given a date, make a correspondance between 1 ARGO profile and NATL60 outputs : Laura's method

# %%
## magics

# %load_ext version_information 
# %version_information numpy,xarray,netCDF4
# Out:
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/formatting.py:16: FutureWarning: The pandas.tslib module is deprecated and will be removed in a future version.
#   from pandas.tslib import OutOfBoundsDatetime
# Software versions
# Python 2.7.13 64bit [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# IPython 5.1.0
# OS Linux 2.6.32 5 amd64 x86_64 with debian 6.0.10
# numpy 1.12.1
# xarray 0.9.1
# netCDF4 1.2.4
# Tue Jul 25 11:47:02 2017 CEST

# %%
## path for mdules

import sys
sys.path.insert(0,"/home/albert/lib/python")

# %%
## imports

import numpy as np
import dask
import xarray as xr
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import pandas as pd 
import datetime
import glob as glob
import matplotlib.gridspec as gridspec
from mpl_toolkits.basemap import Basemap
import time
from dask.diagnostics import ProgressBar

# %matplotlib inline
# Out:
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/formatting.py:16: FutureWarning: The pandas.tslib module is deprecated and will be removed in a future version.
#   from pandas.tslib import OutOfBoundsDatetime

# %%
## datasets

#NATL60

dir="/home/users/albert6a/Data/NATL60/"
file="NATL60-CJM165_y2012m06d14.1d_gridT.nc"

tfile=dir+file

# !ls $tfile
# Out:
# /home/users/albert6a/Data/NATL60/NATL60-CJM165_y2012m06d14.1d_gridT.nc

# %%
#ARGO
dir_ar="/home/users/albert6a/Data/ARGO/"
file062012="EN.4.2.0.f.profiles.g10.201206.nc"
files_ar="EN.4.2.0.f.profiles.g10.2012*.nc"

tfile062012=dir_ar+file062012
tfiles_ar=sorted(glob.glob(dir_ar+files_ar))

# !ls $tfile062012
# Out:
# /home/users/albert6a/Data/ARGO/EN.4.2.0.f.profiles.g10.201206.nc

# %% [markdown]
# ## Select ARGO profiles sampled at 14/06/2012 and within NATL60 boundaries

# %%
ii = 5 # looking at month 6, June:

# Load EN4 data (choose myfilesE12 or 13):
myfileE = tfiles_ar[ii]
print myfileE
dsE = xr.open_dataset(myfileE, lock=False)
latE = dsE.LATITUDE
lonE = dsE.LONGITUDE
depE = dsE.DEPH_CORRECTED
ptempE = dsE.POTM_CORRECTED
psalE = dsE.PSAL_CORRECTED
tE = dsE.JULD
w_inst_type = dsE.WMO_INST_TYPE
    
# Select box region:
lomin=-87
lomax=17
lamin=27
lamax=67

lonEbox = lonE.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)    
latEbox = latE.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)    
tempEbox = ptempE.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)    
salEbox = psalE.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)    
depEbox = depE.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)    
tEbox = tE.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)
w_inst_type_box = w_inst_type.sel(N_PROF=(lonE>lomin)&(lonE<lomax)&(latE>lamin)&(latE<lamax), drop=True)    

tEbox = tEbox.data

jj = 0 # selecting first profile available in June:

observation_lon = lonEbox[jj]
observation_lat = latEbox[jj]
# Out:
# /home/users/albert6a/Data/ARGO/EN.4.2.0.f.profiles.g10.201206.nc

# %%
def find_date(date,year,month,tday):
    prof=[]
    for t in np.arange(0,len(date)):
        ts = pd.to_datetime(str(date[t])) 
        dyear=ts.strftime('%Y')
        dmonth=ts.strftime('%m')
        dday=ts.strftime('%d')
        if dyear == year:
            if dmonth == month:
                if dday == tday:
                    prof.append(t)
        aprof=np.array(prof)
    return aprof

# %%
t14=find_date(tEbox,'2012','06','14')
len(t14)
# Out:
# 209

# %%
observation_lon = lonEbox[t14]
observation_lat = latEbox[t14]
observation_temp =  tempEbox[t14]   
observation_sal =  salEbox[t14]   
observation_dep =   depEbox[t14]  
observation_t = tEbox[t14]

# %% [markdown]
# ## Plot one of the profile

# %%
def plot_profiles(nprof):
    gs = gridspec.GridSpec(2, 2, width_ratios=[1,1], height_ratios=[2,2])

    fig1 = plt.figure(figsize=(14, 16))  # (w,h)
    ax0 = plt.subplot(gs[0, :])
    ax1 = plt.subplot(gs[1, 0])
    ax2 = plt.subplot(gs[1, 1])

    my_map1 = Basemap(projection='merc', lat_0=(lamin+lamax)/2, lon_0=(lomin+lomax)/2, 
    resolution = 'i', ax = ax0,
    llcrnrlon = lomin, llcrnrlat= lamin,
    urcrnrlon = lomax, urcrnrlat = lamax, area_thresh = 10)

    my_map1.drawcoastlines() 
    my_map1.drawmapboundary()
    my_map1.drawmeridians(np.arange(-160, 140, 20), labels=[1,0,0,1], size=18)
    my_map1.drawparallels(np.arange(0, 70, 20), labels=[1,0,0,1], size=18)
    my_map1.scatter(observation_lon[nprof], observation_lat[nprof], latlon=True, c='g', linewidth='0', s=50)

    ax1.plot(observation_temp[nprof],observation_dep[nprof],'b.-')
    ax1.set_xlabel('Potential temperature [$^\circ$C]', size=16)
    ax1.set_ylabel('Depth [m]', size=14)
    ax1.set_ylim(observation_dep[nprof].max().data + 10, 0)
    ax1.grid(True, which='both')
    ax1.xaxis.tick_top()
    ax1.xaxis.set_label_position('top') 
    
    
    ax2.plot(observation_sal[nprof],observation_dep[nprof],'b.-')
    ax2.set_xlabel('Practical salinity [psu]', size=16)
    ax2.set_ylabel('Depth [m]', size=14)
    ax2.set_ylim(observation_dep[nprof].max().data + 10, 0)
    ax2.grid(True, which='both')
    ax2.xaxis.tick_top()
    ax2.xaxis.set_label_position('top')

# %%
plot_profiles(0)
# Out:
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3222: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3231: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
plot_profiles(10)

# %% [markdown]
# ## Find the equivalent NATL60 region,  +/- 1° , at the surface

# %%
#dsN = xr.open_mfdataset(files_model, engine='h5netcdf', chunks={'deptht':30 ,'time_counter':1})
dsN = xr.open_dataset(tfile, chunks={'deptht':30 ,'time_counter':1})

# %%
latN = dsN.nav_lat
lonN = dsN.nav_lon
depN = dsN.deptht
model_temperature = dsN.votemper
model_salinity = dsN.vosaline
timN = dsN.time_counter

# %%
lomin = np.nanmin(lonN)
lomax = np.nanmax(lonN)
lamin = np.nanmin(latN)
lamax = np.nanmax(latN)

# %%
print lomin 
print lomax 
print lamin 
print lamax
# Out:
# -86.255
# 17.7867
# 26.5648
# 67.3871

# %%
model_temperature.shape
# Out:
# (1, 300, 3454, 5422)

# %%
model_temperature_stacked = model_temperature.stack(profile=('x', 'y'))
model_salinity_stacked = model_salinity.stack(profile=('x', 'y'))
lonN_stacked = lonN.stack(profile=('x', 'y'))
latN_stacked = latN.stack(profile=('x', 'y'))

# %%
model_temperature_stacked.shape
# Out:
# (1, 300, 18727588)

# %%
#ces opérations ne marchent qu'avec xarray 0.9.1

distance_threshold = 0.25
square_distance_to_observation = (lonN_stacked - observation_lon[0])**2 + (latN_stacked-observation_lat[0])**2
is_close_to_observation = square_distance_to_observation < distance_threshold**2

model_temperature_near_observation = model_temperature_stacked.where(is_close_to_observation,drop=True)
model_salinity_near_observation = model_salinity_stacked.where(is_close_to_observation, drop=True)
lat_near_observation = latN_stacked.where(is_close_to_observation, drop=True)
lon_near_observation = lonN_stacked.where(is_close_to_observation, drop=True)

# %%
model_temperature_near_observation.shape
# Out:
# (1, 300, 929)

# %%
plt.figure()
plt.scatter(lon_near_observation, lat_near_observation, s=2, c='r', linewidth='0')
plt.scatter(observation_lon[0], observation_lat[0], s=2, c='b', linewidth='0')
plt.show()

# %%
#model_temperature_near_observation.mean(axis=[0, 2]) => MemoryError
#loop over depth => ca marche pas non plus

tem_model_mean=np.zeros(len(depN))
for z in np.arange(len(depN)):
    tem_model_mean[z]=model_temperature_near_observation[0,z,:].mean(axis=[0, 2])

plt.plot(tem_model_mean, depN, 'r.-', label='Natl60')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3a1a01eaaf32> in <module>()
#       4 tem_model_mean=np.zeros(len(depN))
#       5 for z in np.arange(len(depN)):
# ----> 6     tem_model_mean[z]=model_temperature_near_observation[0,z,:].mean(axis=[0, 2])
#       7
#       8 plt.plot(tem_model_mean, depN, 'r.-', label='Natl60')
#
# ValueError: setting an array element with a sequence.

# %%
# %whos
# Out:
# Variable                             Type         Data/Info
# -----------------------------------------------------------
# Basemap                              type         <class 'mpl_toolkits.basemap.Basemap'>
# Dataset                              type         <type 'netCDF4._netCDF4.Dataset'>
# ProgressBar                          type         <class 'dask.diagnostics.progress.ProgressBar'>
# dask                                 module       <module 'dask' from '/hom<...>kages/dask/__init__.pyc'>
# datetime                             module       <module 'datetime' from '<...>lib-dynload/datetime.so'>
# depE                                 DataArray    <xarray.DataArray 'DEPH_C<...>f7.1\n    resolution: 0.1
# depEbox                              DataArray    <xarray.DataArray 'DEPH_C<...>f7.1\n    resolution: 0.1
# depN                                 DataArray    <xarray.DataArray 'deptht<...>    bounds: deptht_bounds
# dir                                  str          /home/users/albert6a/Data/NATL60/
# dir_ar                               str          /home/users/albert6a/Data/ARGO/
# distance_threshold                   float        0.25
# dsE                                  Dataset      <xarray.Dataset>\nDimensi<...>at Apr...\n    NCO: 4.3.2
# dsN                                  Dataset      <object with id 140725904474448 (str() failed)>
# file                                 str          NATL60-CJM165_y2012m06d14.1d_gridT.nc
# file062012                           str          EN.4.2.0.f.profiles.g10.201206.nc
# files_ar                             str          EN.4.2.0.f.profiles.g10.2012*.nc
# find_date                            function     <function find_date at 0x7ffd325d2f50>
# glob                                 module       <module 'glob' from '/hom<...>/lib/python2.7/glob.pyc'>
# gridspec                             module       <module 'matplotlib.grids<...>matplotlib/gridspec.pyc'>
# ii                                   int          5
# is_close_to_observation              DataArray    <xarray.DataArray (profil<...> 12 13 14 15 16 17 18 ...
# jj                                   int          0
# lamax                                float32      67.3871
# lamin                                float32      26.5648
# latE                                 DataArray    <xarray.DataArray 'LATITU<...>90.0\n    valid_max: 90.0
# latEbox                              DataArray    <xarray.DataArray 'LATITU<...>90.0\n    valid_max: 90.0
# latN                                 DataArray    <xarray.DataArray 'nav_la<...>th\n    nav_model: grid_T
# latN_stacked                         DataArray    <xarray.DataArray 'nav_la<...>th\n    nav_model: grid_T
# lat_near_observation                 DataArray    <xarray.DataArray (profil<...>th\n    nav_model: grid_T
# lomax                                float32      17.7867
# lomin                                float32      -86.255
# lonE                                 DataArray    <xarray.DataArray 'LONGIT<...>0.0\n    valid_max: 180.0
# lonEbox                              DataArray    <xarray.DataArray 'LONGIT<...>0.0\n    valid_max: 180.0
# lonN                                 DataArray    <xarray.DataArray 'nav_lo<...>st\n    nav_model: grid_T
# lonN_stacked                         DataArray    <xarray.DataArray 'nav_lo<...>st\n    nav_model: grid_T
# lon_near_observation                 DataArray    <xarray.DataArray (profil<...>st\n    nav_model: grid_T
# max_prof_temp                        ndarray      300: 300 elems, type `float64`, 2400 bytes
# mean_prof_temp                       ndarray      300: 300 elems, type `float64`, 2400 bytes
# min_prof_temp                        ndarray      300: 300 elems, type `float64`, 2400 bytes
# model_salinity                       DataArray    <xarray.DataArray 'vosali<...>e: mean (interval: 100 s)
# model_salinity_near_observation      DataArray    <xarray.DataArray (time_c<...>e: mean (interval: 100 s)
# model_salinity_stacked               DataArray    <xarray.DataArray 'vosali<...>e: mean (interval: 100 s)
# model_temperature                    DataArray    <xarray.DataArray 'votemp<...>e: mean (interval: 100 s)
# model_temperature_near_observation   DataArray    <xarray.DataArray (time_c<...>e: mean (interval: 100 s)
# model_temperature_stacked            DataArray    <xarray.DataArray 'votemp<...>e: mean (interval: 100 s)
# myfileE                              str          /home/users/albert6a/Data<...>.f.profiles.g10.201206.nc
# np                                   module       <module 'numpy' from '/ho<...>ages/numpy/__init__.pyc'>
# observation_dep                      DataArray    <xarray.DataArray 'DEPH_C<...>f7.1\n    resolution: 0.1
# observation_lat                      DataArray    <xarray.DataArray 'LATITU<...>90.0\n    valid_max: 90.0
# observation_lon                      DataArray    <xarray.DataArray 'LONGIT<...>0.0\n    valid_max: 180.0
# observation_sal                      DataArray    <xarray.DataArray 'PSAL_C<...>.3\n    resolution: 0.001
# observation_t                        ndarray      209: 209 elems, type `datetime64[ns]`, 1672 bytes
# observation_temp                     DataArray    <xarray.DataArray 'POTM_C<...>.3\n    resolution: 0.001
# pd                                   module       <module 'pandas' from '/h<...>ges/pandas/__init__.pyc'>
# plot_profiles                        function     <function plot_profiles at 0x7ffd32602230>
# plt                                  module       <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# psalE                                DataArray    <xarray.DataArray 'PSAL_C<...>.3\n    resolution: 0.001
# ptempE                               DataArray    <xarray.DataArray 'POTM_C<...>.3\n    resolution: 0.001
# salEbox                              DataArray    <xarray.DataArray 'PSAL_C<...>.3\n    resolution: 0.001
# square_distance_to_observation       DataArray    <xarray.DataArray (profil<...> 12 13 14 15 16 17 18 ...
# sys                                  module       <module 'sys' (built-in)>
# t14                                  ndarray      209: 209 elems, type `int64`, 1672 bytes
# tE                                   DataArray    <xarray.DataArray 'JULD' <...>\n    _fillvalue: 99999.0
# tEbox                                ndarray      6459: 6459 elems, type `datetime64[ns]`, 51672 bytes
# tem_model_mean                       ndarray      300: 300 elems, type `float64`, 2400 bytes
# tempEbox                             DataArray    <xarray.DataArray 'POTM_C<...>.3\n    resolution: 0.001
# tfile                                str          /home/users/albert6a/Data<...>5_y2012m06d14.1d_gridT.nc
# tfile062012                          str          /home/users/albert6a/Data<...>.f.profiles.g10.201206.nc
# tfiles_ar                            list         n=12
# timN                                 DataArray    <xarray.DataArray 'time_c<...>unds: time_counter_bounds
# time                                 module       <module 'time' from '/hom<...>2.7/lib-dynload/time.so'>
# truc                                 DataArray    <xarray.DataArray (profil<...>e: mean (interval: 100 s)
# w_inst_type                          DataArray    <xarray.DataArray 'WMO_IN<...>le 1770 - instrument type
# w_inst_type_box                      DataArray    <xarray.DataArray 'WMO_IN<...>le 1770 - instrument type
# xr                                   module       <module 'xarray' from '/h<...>ges/xarray/__init__.pyc'>
# z                                    int64        0

# %%
# %xdel lonval
# %xdel latval
# Out:
# NameError: name 'lonval' is not defined

# %%
truc=model_temperature_near_observation[0,0]
truc.values
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-40-9d69741d5599> in <module>()
#       1 truc=model_temperature_near_observation[0,0]
# ----> 2 truc.values
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/dataarray.pyc in values(self)
#     398     def values(self):
#     399         """The array's data as a numpy.ndarray"""
# --> 400         return self.variable.values
#     401
#     402     @values.setter
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/variable.pyc in values(self)
#     304     def values(self):
#     305         """The variable's data as a numpy.ndarray"""
# --> 306         return _as_array_or_item(self._data)
#     307
#     308     @values.setter
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/variable.pyc in _as_array_or_item(data)
#     180     TODO: remove this (replace with np.asarray) once these issues are fixed
#     181     """
# --> 182     data = np.asarray(data)
#     183     if data.ndim == 0:
#     184         if data.dtype.kind == 'M':
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/array/core.pyc in __array__(self, dtype, **kwargs)
#     852
#     853     def __array__(self, dtype=None, **kwargs):
# --> 854         x = self.compute()
#     855         if dtype and x.dtype != dtype:
#     856             x = x.astype(dtype)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/base.pyc in compute(self, **kwargs)
#      35
#      36     def compute(self, **kwargs):
# ---> 37         return compute(self, **kwargs)[0]
#      38
#      39     @classmethod
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/base.pyc in compute(*args, **kwargs)
#     108                 for opt, val in groups.items()])
#     109     keys = [var._keys() for var in variables]
# --> 110     results = get(dsk, keys, **kwargs)
#     111
#     112     results_iter = iter(results)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/threaded.pyc in get(dsk, result, cache, num_workers, **kwargs)
#      55     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      56                         cache=cache, queue=queue, get_id=_thread_get_id,
# ---> 57                         **kwargs)
#      58
#      59     return results
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.pyc in get_async(apply_async, num_workers, dsk, result, cache, queue, get_id, raise_on_exception, rerun_exceptions_locally, callbacks, **kwargs)
#     479                 _execute_task(task, data)  # Re-execute locally
#     480             else:
# --> 481                 raise(remote_exception(res, tb))
#     482         state['cache'][key] = res
#     483         finish_task(dsk, key, state, results, keyorder.get)
#
# MemoryError:
#
# Traceback
# ---------
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 264, in execute_task
#     result = _execute_task(task, data)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 246, in _execute_task
#     return func(*args2)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/array/core.py", line 50, in getarray
#     c = np.asarray(c)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py", line 531, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py", line 398, in __array__
#     return np.asarray(self.array, dtype=dtype)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py", line 531, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py", line 373, in __array__
#     return np.asarray(array[self.key], dtype=None)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/conventions.py", line 363, in __getitem__
#     self.scale_factor, self.add_offset, self._dtype)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/conventions.py", line 59, in mask_and_scale
#     values = np.array(array, dtype=dtype, copy=True)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py", line 373, in __array__
#     return np.asarray(array[self.key], dtype=None)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/backends/netCDF4_.py", line 56, in __getitem__
#     data = getitem(self.array, key)
#   File "netCDF4/_netCDF4.pyx", line 3676, in netCDF4._netCDF4.Variable.__getitem__ (netCDF4/_netCDF4.c:39023)

# %%
def plot_profiles_obs_and_model(nprof):

    distance_threshold = 0.25
    square_distance_to_observation = (lonN_stacked - observation_lon[nprof])**2 + (latN_stacked-observation_lat[nprof])**2
    is_close_to_observation = square_distance_to_observation < distance_threshold**2

    model_temperature_near_observation = model_temperature_stacked.where(is_close_to_observation,drop=True)
    model_salinity_near_observation = model_salinity_stacked.where(is_close_to_observation, drop=True)
    lat_near_observation = latN_stacked.where(is_close_to_observation, drop=True)
    lon_near_observation = lonN_stacked.where(is_close_to_observation, drop=True)

    tem_model_mean = model_temperature_near_observation.mean(axis=[0, 2])
    sal_model_mean = model_salinity_near_observation.mean(axis=[0, 2])
    
    gs = gridspec.GridSpec(2, 2, width_ratios=[1,1], height_ratios=[2,2])

    fig1 = plt.figure(figsize=(14, 16))  # (w,h)
    ax0 = plt.subplot(gs[0, :])
    ax1 = plt.subplot(gs[1, 0])
    ax2 = plt.subplot(gs[1, 1])

    my_map1 = Basemap(projection='merc', lat_0=(lamin+lamax)/2, lon_0=(lomin+lomax)/2, 
    resolution = 'i', ax = ax0,
    llcrnrlon = lomin, llcrnrlat= lamin,
    urcrnrlon = lomax, urcrnrlat = lamax, area_thresh = 10)

    my_map1.drawcoastlines() 
    my_map1.drawmapboundary()
    my_map1.drawmeridians(np.arange(-160, 140, 20), labels=[1,0,0,1], size=18)
    my_map1.drawparallels(np.arange(0, 70, 20), labels=[1,0,0,1], size=18)
    my_map1.scatter(lon_near_observation.to_masked_array(), lat_near_observation.to_masked_array(), latlon=True, c='r', linewidth='0', s=50)
    my_map1.scatter(observation_lon[nprof], observation_lat[nprof], latlon=True, c='g', linewidth='0', s=50)

    ax1.plot(observation_temp[nprof],observation_dep[nprof],'b.-')
    ax1.plot(tem_model_mean, depN, 'r.-', label='Natl60')
    ax1.set_xlabel('Potential temperature [$^\circ$C]', size=16)
    ax1.set_ylabel('Depth [m]', size=14)
    ax1.set_ylim(observation_dep[nprof].max().data + 10, 0)
    ax1.grid(True, which='both')
    ax1.xaxis.tick_top()
    ax1.xaxis.set_label_position('top') 
    
    
    ax2.plot(observation_sal[nprof],observation_dep[nprof],'b.-')
    ax2.plot(sal_model_mean, depN, 'r.-', label='Natl60')
    ax2.set_xlabel('Practical salinity [psu]', size=16)
    ax2.set_ylabel('Depth [m]', size=14)
    ax2.set_ylim(observation_dep[nprof].max().data + 10, 0)
    ax2.grid(True, which='both')
    ax2.xaxis.tick_top()
    ax2.xaxis.set_label_position('top')

# %%
#12:04
plot_profiles_obs_and_model(0)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-30-f09124f199eb> in <module>()
# ----> 1 plot_profiles_obs_and_model(0)
#
# <ipython-input-28-870f53ad7498> in plot_profiles_obs_and_model(nprof)
#      33
#      34     ax1.plot(observation_temp[nprof],observation_dep[nprof],'b.-')
# ---> 35     ax1.plot(tem_model_mean, depN, 'r.-', label='Natl60')
#      36     ax1.set_xlabel('Potential temperature [$^\circ$C]', size=16)
#      37     ax1.set_ylabel('Depth [m]', size=14)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     378
#     379         if len(tup) == 2:
# --> 380             x = _check_1d(tup[0])
#     381             y = _check_1d(tup[-1])
#     382         else:
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/matplotlib/cbook.pyc in _check_1d(x)
#    2225             return x
#    2226         except (IndexError, TypeError):
# -> 2227             return np.atleast_1d(x)
#    2228
#    2229
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/shape_base.pyc in atleast_1d(*arys)
#      48     res = []
#      49     for ary in arys:
# ---> 50         ary = asanyarray(ary)
#      51         if len(ary.shape) == 0:
#      52             result = ary.reshape(1)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.pyc in asanyarray(a, dtype, order)
#     581
#     582     """
# --> 583     return array(a, dtype, copy=False, order=order, subok=True)
#     584
#     585
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/common.pyc in __array__(self, dtype)
#     149
#     150     def __array__(self, dtype=None):
# --> 151         return np.asarray(self.values, dtype=dtype)
#     152
#     153     def __repr__(self):
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/dataarray.pyc in values(self)
#     398     def values(self):
#     399         """The array's data as a numpy.ndarray"""
# --> 400         return self.variable.values
#     401
#     402     @values.setter
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/variable.pyc in values(self)
#     304     def values(self):
#     305         """The variable's data as a numpy.ndarray"""
# --> 306         return _as_array_or_item(self._data)
#     307
#     308     @values.setter
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/variable.pyc in _as_array_or_item(data)
#     180     TODO: remove this (replace with np.asarray) once these issues are fixed
#     181     """
# --> 182     data = np.asarray(data)
#     183     if data.ndim == 0:
#     184         if data.dtype.kind == 'M':
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/array/core.pyc in __array__(self, dtype, **kwargs)
#     852
#     853     def __array__(self, dtype=None, **kwargs):
# --> 854         x = self.compute()
#     855         if dtype and x.dtype != dtype:
#     856             x = x.astype(dtype)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/base.pyc in compute(self, **kwargs)
#      35
#      36     def compute(self, **kwargs):
# ---> 37         return compute(self, **kwargs)[0]
#      38
#      39     @classmethod
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/base.pyc in compute(*args, **kwargs)
#     108                 for opt, val in groups.items()])
#     109     keys = [var._keys() for var in variables]
# --> 110     results = get(dsk, keys, **kwargs)
#     111
#     112     results_iter = iter(results)
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/threaded.pyc in get(dsk, result, cache, num_workers, **kwargs)
#      55     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      56                         cache=cache, queue=queue, get_id=_thread_get_id,
# ---> 57                         **kwargs)
#      58
#      59     return results
#
# /home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.pyc in get_async(apply_async, num_workers, dsk, result, cache, queue, get_id, raise_on_exception, rerun_exceptions_locally, callbacks, **kwargs)
#     479                 _execute_task(task, data)  # Re-execute locally
#     480             else:
# --> 481                 raise(remote_exception(res, tb))
#     482         state['cache'][key] = res
#     483         finish_task(dsk, key, state, results, keyorder.get)
#
# MemoryError:
#
# Traceback
# ---------
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 264, in execute_task
#     result = _execute_task(task, data)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 245, in _execute_task
#     args2 = [_execute_task(a, cache) for a in args]
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/async.py", line 246, in _execute_task
#     return func(*args2)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/dask/array/core.py", line 50, in getarray
#     c = np.asarray(c)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py", line 531, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py", line 398, in __array__
#     return np.asarray(self.array, dtype=dtype)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py", line 531, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py", line 373, in __array__
#     return np.asarray(array[self.key], dtype=None)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/conventions.py", line 363, in __getitem__
#     self.scale_factor, self.add_offset, self._dtype)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/conventions.py", line 59, in mask_and_scale
#     values = np.array(array, dtype=dtype, copy=True)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py", line 373, in __array__
#     return np.asarray(array[self.key], dtype=None)
#   File "/home/users/albert6a/anaconda2/lib/python2.7/site-packages/xarray/backends/netCDF4_.py", line 56, in __getitem__
#     data = getitem(self.array, key)
#   File "netCDF4/_netCDF4.pyx", line 3676, in netCDF4._netCDF4.Variable.__getitem__ (netCDF4/_netCDF4.c:39023)

# %%
natl60=xr.open_dataset(tfile)
dep_nat=natl60['deptht']
lat_nat=natl60['nav_lat']
lon_nat=natl60['nav_lon']
temp_nat=natl60['votemper']
sal_nat=natl60['vosaline']
day_nat=natl60['time_counter']

# %%
len(dep_nat.values)
# Out:
# 300

# %%
latval=lat_nat.values
lonval=lon_nat.values
tempval=temp_nat[0,0].values
salval=sal_nat[0,0].values

# %%
tempval.shape
# Out:
# (3454, 5422)

# %%
def select_region_temp(latr,lonr):
    templat=tempval[np.where(np.abs(latval-latr)<1)]
    lonlat=lonval[np.where(np.abs(latval-latr)<1)]
    tempr=templat[np.where(np.abs(lonlat-lonr)<1)]
    return tempr

# %%
temp37N63W=select_region_temp(37,-63)

# %%
print 'taille=',temp37N63W.shape
print 'mean=',np.mean(temp37N63W)
print 'min=',np.min(temp37N63W)
print 'max=',np.max(temp37N63W)
# Out:
# taille= (18672,)
# mean= 23.3423507441
# min= 19.0094432831
# max= 25.6885318756

# %%
def select_region_sal(latr,lonr):
    sallat=salval[np.where(np.abs(latval-latr)<1)]
    lonlat=lonval[np.where(np.abs(latval-latr)<1)]
    salr=sallat[np.where(np.abs(lonlat-lonr)<1)]
    return salr

# %%
sal37N63W=select_region_sal(37,-63)

# %%
print 'taille=',sal37N63W.shape
print 'mean=',np.mean(sal37N63W)
print 'min=',np.min(sal37N63W)
print 'max=',np.max(sal37N63W)
# Out:
# taille= (18672,)
# mean= 36.4046774711
# min= 34.9465904236
# max= 36.5759429932

# %% [markdown]
# ## Loop over depth

# %%
def select_profiles_temp(latr,lonr):
    latval=lat_nat.values
    lonval=lon_nat.values
    mean_prof_temp=np.zeros(len(dep_nat.values))
    min_prof_temp=np.zeros(len(dep_nat.values))
    max_prof_temp=np.zeros(len(dep_nat.values))
    for z in np.arange(len(dep_nat.values)):
        tempval=temp_nat[0,z].values
        templat=tempval[np.where(np.abs(latval-latr)<1)]
        lonlat=lonval[np.where(np.abs(latval-latr)<1)]
        tempz=templat[np.where(np.abs(lonlat-lonr)<1)]
        mean_prof_temp[z]=np.mean(tempz)
        min_prof_temp[z]=np.min(tempz)
        max_prof_temp[z]=np.max(tempz)
    return mean_prof_temp, min_prof_temp, max_prof_temp

# %%
mean_temp37N63W,min_temp37N63W,max_temp37N63W=select_profiles_temp(37,-63)

# %%
mean_temp37N63W.shape
# Out:
# (300,)

# %% [markdown]
# ##Plot All

# %%
def plot_temp_profile_all(nprof,meant,mint,maxt,depmod):
    plt.plot(temp_ar[nprof,:],-1*dep_ar[nprof,:])
    plt.xlabel('Potential temperature')
    plt.ylabel('depth')
    plt.plot(meant,-1*depmod,'k-')
    plt.plot(mint,-1*depmod,'k.')
    plt.plot(maxt,-1*depmod,'k--')
    plt.legend(['ARGO','mean NATL60','min NATL60','max NATL60'])
    ts = pd.to_datetime(str(day_ar.values[nprof])) 
    d = ts.strftime('%Y.%m.%d')
    title="ARGO profile at lat "+str(np.trunc(lat_ar.values[nprof]))+"deg N and lon "+str(np.trunc(lon_ar.values[nprof]))+"deg E "+str(d)
    plt.title(title)

# %%
plot_temp_profile_all(t14natl[0],mean_temp37N63W,min_temp37N63W,max_temp37N63W,dep_nat)

# %%
def select_profiles_sal(latr,lonr):
    latval=lat_nat.values
    lonval=lon_nat.values
    mean_prof_sal=np.zeros(len(dep_nat.values))
    min_prof_sal=np.zeros(len(dep_nat.values))
    max_prof_sal=np.zeros(len(dep_nat.values))
    for z in np.arange(len(dep_nat.values)):
        salval=sal_nat[0,z].values
        sallat=salval[np.where(np.abs(latval-latr)<1)]
        lonlat=lonval[np.where(np.abs(latval-latr)<1)]
        salz=sallat[np.where(np.abs(lonlat-lonr)<1)]
        mean_prof_sal[z]=np.mean(salz)
        min_prof_sal[z]=np.min(salz)
        max_prof_sal[z]=np.max(salz)
    return mean_prof_sal, min_prof_sal, max_prof_sal
mean_sal37N63W,min_sal37N63W,max_sal37N63W=select_profiles_sal(37,-63)

# %%
def plot_sal_profile_all(nprof,meant,mint,maxt,depmod):
    plt.plot(sal_ar[nprof,:],-1*dep_ar[nprof,:])
    plt.xlabel('Practical salinity')
    plt.ylabel('depth')
    plt.plot(meant,-1*depmod,'k-')
    plt.plot(mint,-1*depmod,'k.')
    plt.plot(maxt,-1*depmod,'k--')
    plt.legend(['ARGO','mean NATL60','min NATL60','max NATL60'])
    ts = pd.to_datetime(str(day_ar.values[nprof])) 
    d = ts.strftime('%Y.%m.%d')
    title="ARGO profile at lat "+str(np.trunc(lat_ar.values[nprof]))+"deg N and lon "+str(np.trunc(lon_ar.values[nprof]))+"deg E "+str(d)
    plt.title(title)
plot_sal_profile_all(t14natl[0],mean_sal37N63W,min_sal37N63W,max_sal37N63W,dep_nat)
