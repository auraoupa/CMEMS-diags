# %% [markdown]
# # Filtering all dates, writing a file containing filtered data and plotting results

# %% [markdown]
# __source__ : copy 2017-04-20-AA-make-2D-filt-write-file-and-plot.ipynb with different size of window for Lanczos filtering and different month of application

# %% [markdown]
# ## 1. Importing external modules

# %%
## magics

# %load_ext version_information 
# %version_information numpy,xarray,netCDF4
# Out:
# Software versions
# Python 2.7.11 64bit [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# IPython 4.2.0
# OS Linux 3.16.0 4 amd64 x86_64 with debian 8.5
# numpy 1.11.1
# xarray 0.9.1
# netCDF4 1.2.4
# Thu May 04 10:13:01 2017 CEST

# %%
## path for mdules

import sys
sys.path.insert(0,"/home/albert/lib/python")

# %%
## imports

import numpy as np
import dask
import xarray as xr
import GriddedData
import time

# %%
#- Other modules
import os
from glob import glob
import numpy.ma as ma
import scipy as sc
import WavenumberSpectrum as ws
import dask.array as da
from netCDF4 import Dataset

### palette
from matplotlib.colors import LogNorm
import matplotlib.cm as mplcm
import colormap as cmaps
import matplotlib.cm as cm

import seaborn as sns

seq_cmap = mplcm.Blues
div_cmap = mplcm.seismic

### quick plot
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

## local/specific imports
import oocgcm
import oocgcm.filtering
import oocgcm.filtering.linearfilters as tf
# %matplotlib inline

# %% [markdown]
# ## 2. Dataset

# %%
dir="/media/extra/DATA/NATL60/NATL60-CJM165-S/"
files01="NATL60-CJM165_y2013m01d*.1d_curloverf.nc"
files02="NATL60-CJM165_y2013m02d*.1d_curloverf.nc"
files03="NATL60-CJM165_y2013m03d*.1d_curloverf.nc"
files09="NATL60-CJM165_y2013m09d*.1d_curloverf.nc"

tfiles01=dir+files01
tfiles02=dir+files02
tfiles03=dir+files03
tfiles09=dir+files09

# !ls $tfiles02
# Out:
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d01.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d02.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d03.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d04.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d05.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d06.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d07.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d08.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d09.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d10.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d11.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d12.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d13.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d14.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d15.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d16.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d17.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d18.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d19.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d20.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d21.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d22.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d23.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d24.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d25.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d26.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d27.1d_curloverf.nc
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m02d28.1d_curloverf.nc

# %% [markdown]
# ## 4. 2D filtering

# %%
gridfile="/media/extra/DATA/NATL60/NATL60-I/NATL60_grid.nc"
# !ls $gridfile
grid=xr.open_dataset(gridfile)
navlat= grid['nav_lat']
navlon= grid['nav_lon']

def plot_and_save_curl_total_filt(curl,signal_LS,t,month):
    cont=np.isnan(curl)
    plt.figure(figsize=(15,33))
    ax = plt.subplot(311)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(curl),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title('Total surface relative vorticity '+str(t)+' month '+str(month),fontsize=25)
    cont=np.isnan(signal_LS)
    ax = plt.subplot(312)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(signal_LS),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title('Large scale surface relative vorticity '+str(t)+' month '+str(month),fontsize=25)
    signal_SS=curl-signal_LS
    cont=np.isnan(signal_SS)
    ax = plt.subplot(313)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(signal_SS),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title('Small scale surface relative vorticity '+str(t)+' month '+str(month),fontsize=25)
    figname='/media/extra/DATA/NATL60/NATL60-CJM165-PLOTS/filt_socurloverf/filtering_socurloverf_NATL60-CJM165_'+str(t)+'0'+str(month)+'.png'
    plt.savefig(figname)
# Out:
# /media/extra/DATA/NATL60/NATL60-I/NATL60_grid.nc

# %%
def plot_and_save_curl_total_filt_sept(curl,signal_LS,t):
    cont=np.isnan(curl)
    plt.figure(figsize=(15,33))
    ax = plt.subplot(311)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(curl),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title('Total surface relative vorticity '+str(t)+' sept',fontsize=25)
    cont=np.isnan(signal_LS)
    ax = plt.subplot(312)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(signal_LS),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title('Large scale surface relative vorticity '+str(t)+' sept',fontsize=25)
    signal_SS=curl-signal_LS
    cont=np.isnan(signal_SS)
    ax = plt.subplot(313)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(signal_SS),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title('Small scale surface relative vorticity '+str(t)+' sept',fontsize=25)
    figname='/media/extra/DATA/NATL60/NATL60-CJM165-PLOTS/filt_socurloverf/filtering_socurloverf_NATL60-CJM165_'+str(t)+'09.png'
    plt.savefig(figname)

# %%
curls = xr.open_mfdataset(tfiles03,concat_dim='time_counter')['socurloverf']


for t in np.arange(0,1):
    print t
    filename='/media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m03d'+str(t+1)+'.1d_socurloverf_filt2deg_n30.nc'
    print filename
    filtset = Dataset(filename, 'w', format='NETCDF4')
    filtset.description = "NATL60 data filtered with Lanczos filter with cut-off frequency of 2deg"
    
    time=filtset.createDimension('time_counter',None)
    x=filtset.createDimension('x', 5422)
    y=filtset.createDimension('y', 3454)

    lat = filtset.createVariable('nav_lat', 'f8', ('y','x'))
    lat.standart_name="latitude"
    lat.long_name = "Latitude" 
    lat.units = "degrees_north"
    lat.nav_model = "grid_U"

    lon = filtset.createVariable('nav_lon', 'f8', ('y','x'))
    lon.standard_name = "longitude" 
    lon.long_name = "Longitude" 
    lon.units = "degrees_east" 
    lon.nav_model = "grid_U" 
    
    time = filtset.createVariable('time_counter', 'f8', ('time_counter'))
    time.axis = "T" 
    time.standard_name = "time" 
    time.long_name = "Time axis" 
    time.calendar = "gregorian" 
    time.units = "seconds since 1958-01-01 00:00:00" 
    time.time_origin = "1958-01-01 00:00:00" 
    time.bounds = "time_counter_bounds" 

    socurloverf = filtset.createVariable('socurloverf', 'f8', ('time_counter','y','x'),fill_value=0.)
    socurloverf.units = "-" 
    socurloverf.valid_min = -1000.
    socurloverf.valid_max = 1000.
    socurloverf.long_name = "Filtered Relative_Vorticity (curl)" 
    socurloverf.short_name = "socurl" 
    socurloverf.iweight = 1 
    socurloverf.online_operation = "N/A" 
    socurloverf.axis = "TYX" 
    socurloverf.scale_factor = 1.
    socurloverf.add_offset = 0.
    socurloverf.savelog10 = 0. 

    curl0=curls[t]
    win_box2D = curl0.win
    win_box2D.set(window_name='lanczos', n=[30, 30], dims=['x', 'y'], fc=0.00833)
    bw = win_box2D.boundary_weights(drop_dims=[])
    signal_LS = win_box2D.apply(weights=bw)
    plot_and_save_curl_total_filt(curl0,signal_LS,t+1,3)
    signal_SS=curl0-signal_LS
    truc=np.zeros((1,3454,5422))
    truc[0,:,:]=signal_SS[:,:]
    socurloverf[0,:,:] = truc[0,:,:]
    filtset.close()  # close the new file

    del curl0,win_box2D,bw,signal_LS,signal_SS,truc
# Out:
# 0
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m03d1.1d_socurloverf_filt2deg_n30.nc
# /home/albert/lib/python/oocgcm-0.1.0-py2.7.egg/oocgcm/filtering/linearfilters.py:58: RuntimeWarning: invalid value encountered in divide
#   np.sin(np.pi * k / (n / 2.)) / (np.pi * k / (n / 2.)))
# [########################################] | 100% Completed |  1min  2.5s

# %%
curls = xr.open_mfdataset(tfiles09,concat_dim='time_counter')['socurloverf']


for t in np.arange(30,31):
    print t
    filename='/media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m09d'+str(t+1)+'.1d_socurloverf_filt2deg.nc'
    print filename
    filtset = Dataset(filename, 'w', format='NETCDF4')
    filtset.description = "NATL60 data filtered with Lanczos filter with cut-off frequency of 2deg"
    
    time=filtset.createDimension('time_counter',None)
    x=filtset.createDimension('x', 5422)
    y=filtset.createDimension('y', 3454)

    lat = filtset.createVariable('nav_lat', 'f8', ('y','x'))
    lat.standart_name="latitude"
    lat.long_name = "Latitude" 
    lat.units = "degrees_north"
    lat.nav_model = "grid_U"

    lon = filtset.createVariable('nav_lon', 'f8', ('y','x'))
    lon.standard_name = "longitude" 
    lon.long_name = "Longitude" 
    lon.units = "degrees_east" 
    lon.nav_model = "grid_U" 
    
    time = filtset.createVariable('time_counter', 'f8', ('time_counter'))
    time.axis = "T" 
    time.standard_name = "time" 
    time.long_name = "Time axis" 
    time.calendar = "gregorian" 
    time.units = "seconds since 1958-01-01 00:00:00" 
    time.time_origin = "1958-01-01 00:00:00" 
    time.bounds = "time_counter_bounds" 

    socurloverf = filtset.createVariable('socurloverf', 'f8', ('time_counter','y','x'),fill_value=0.)
    socurloverf.units = "-" 
    socurloverf.valid_min = -1000.
    socurloverf.valid_max = 1000.
    socurloverf.long_name = "Filtered Relative_Vorticity (curl)" 
    socurloverf.short_name = "socurl" 
    socurloverf.iweight = 1 
    socurloverf.online_operation = "N/A" 
    socurloverf.axis = "TYX" 
    socurloverf.scale_factor = 1.
    socurloverf.add_offset = 0.
    socurloverf.savelog10 = 0. 

    curl0=curls[t]
    win_box2D = curl0.win
    win_box2D.set(window_name='lanczos', n=[120, 120], dims=['x', 'y'], fc=0.00833)
    bw = win_box2D.boundary_weights(drop_dims=[])
    signal_LS = win_box2D.apply(weights=bw)
    plot_and_save_curl_total_filt_sept(curl0,signal_LS,t+1)
    signal_SS=curl0-signal_LS
    truc=np.zeros((1,3454,5422))
    truc[0,:,:]=signal_SS[:,:]
    socurloverf[0,:,:] = truc[0,:,:]
    filtset.close()  # close the new file
# Out:
# 30
# /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m09d31.1d_socurloverf_filt2deg.nc
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-0504f9367133> in <module>()
#      47     socurloverf.savelog10 = 0.
#      48
# ---> 49     curl0=curls[t]
#      50     win_box2D = curl0.win
#      51     win_box2D.set(window_name='lanczos', n=[120, 120], dims=['x', 'y'], fc=0.00833)
#
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/dataarray.pyc in __getitem__(self, key)
#     467         else:
#     468             # orthogonal array indexing
# --> 469             return self.isel(**self._item_key_to_dict(key))
#     470
#     471     def __setitem__(self, key, value):
#
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/dataarray.pyc in isel(self, drop, **indexers)
#     655         DataArray.sel
#     656         """
# --> 657         ds = self._to_temp_dataset().isel(drop=drop, **indexers)
#     658         return self._from_temp_dataset(ds)
#     659
#
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/dataset.pyc in isel(self, drop, **indexers)
#    1117         for name, var in iteritems(self._variables):
#    1118             var_indexers = dict((k, v) for k, v in indexers if k in var.dims)
# -> 1119             new_var = var.isel(**var_indexers)
#    1120             if not (drop and name in var_indexers):
#    1121                 variables[name] = new_var
#
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/variable.pyc in isel(self, **indexers)
#     545             if dim in indexers:
#     546                 key[i] = indexers[dim]
# --> 547         return self[tuple(key)]
#     548
#     549     def squeeze(self, dim=None):
#
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/variable.pyc in __getitem__(self, key)
#    1189     def __getitem__(self, key):
#    1190         key = self._item_key_to_tuple(key)
# -> 1191         values = self._indexable_data[key]
#    1192         if not hasattr(values, 'ndim') or values.ndim == 0:
#    1193             return Variable((), values, self._attrs, self._encoding)
#
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.pyc in __getitem__(self, key)
#     533             key, = key
#     534
# --> 535         result = self.array[key]
#     536
#     537         if isinstance(result, pd.Index):
#
# /home/albert/anaconda2/lib/python2.7/site-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 30 is out of bounds for axis 0 with size 30

# %%
curls.shape
# Out:
# (30, 3454, 5422)
